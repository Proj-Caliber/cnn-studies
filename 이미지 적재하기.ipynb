# %% [markdown]
# ## 이미지 데이터 정리

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# # # 데이터 압축 풀기 PE
# path_to_zip_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PE.zip'
# directory_extract_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PE'

# import zipfile
# with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#   zip_ref.extractall(directory_extract_file)

# # # 데이터 압축 풀기 PS
# path_to_zip_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PS.zip'
# directory_extract_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PS'

# import zipfile
# with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#   zip_ref.extractall(directory_extract_file)

# # # 데이터 압축 풀기 PET
# path_to_zip_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PET.zip'
# directory_extract_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PET'

# import zipfile
# with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#   zip_ref.extractall(directory_extract_file)

# # # 데이터 압축 풀기 PP
# path_to_zip_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PP.zip'
# directory_extract_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/PP'

# import zipfile
# with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#   zip_ref.extractall(directory_extract_file)

# %% [markdown]
# ## annotation정리

# %%
# import zipfile

# data_list = ['PE','PET','PP','PS']
# for i in data_list:
#   path_to_zip_file = f'/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/annotation/{i}/train_annotation_{i}.zip'
#   directory_extract_file = f'/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/annotation/{i}'
#   with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#     zip_ref.extractall(directory_extract_file)

# %% [markdown]
# bbox도 있고 instance segmentation도 있으니 이 부분을 어떻게 적용시킬까? ㅜㅜ

# %%
## 일단 데이터가 너무 이상하게 되어 있다 ㅜㅜ 그래서 이 부분을 과연 해결해야하는가?
## https://ourcstory.tistory.com/96 참고해서 적용시킬 것

## 라벨링의 정리를 위한 class를 짜야할 것 같다
## instance segmentation에 관련하여 문제를 푸는 방법도 알아놔야 할 것 같다
## YML공부 어케하지...? ㅜㅜ

# %% [markdown]
# ## Test 데이터 정리

# %%
# # Test 압축 풀기 PP
# path_to_zip_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/download.zip'
# directory_extract_file = '/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data'

# import zipfile
# with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#   zip_ref.extractall(directory_extract_file)

# %%
data_list = ['PE','PET','PP','PS']
import zipfile

# for i in data_list:
#   path_to_zip_file = f'/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/Test/annotations/{i}/test_annotation_{i}.zip'
#   directory_extract_file = f'/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/Test/annotations/{i}'
#   with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#     zip_ref.extractall(directory_extract_file)

## 데이터가 잘못 적재되어 있기 때문에 다른 방식으로 적재를 시작한다.

# i = 'PS'
# path_to_zip_file = f'/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/Test/annotations/{i}/test_annotation_{i}.zip'
# directory_extract_file = f'/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/Test/annotations/{i}'

# with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#   zip_ref.extractall(directory_extract_file)

# %% [markdown]
# ## 데이터 어떻게 쌓았는가

# %%
# !sudo apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tree is already the newest version (1.7.0-5).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
import os
os.chdir('/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data')

# %%
# !tree -L 3 -d
# Out:
# .
# ├── Test
# │   ├── annotations
# │   │   ├── PE
# │   │   ├── PET
# │   │   ├── PP
# │   │   └── PS
# │   ├── PE
# │   ├── PET
# │   ├── PP
# │   └── PS
# └── Train
#     ├── annotation
#     │   ├── PE
#     │   ├── PET
#     │   ├── PP
#     │   └── PS
#     ├── PE
#     ├── PET
#     ├── PP
#     └── PS
#
# 20 directories

# %% [markdown]
# ## 라벨링 작업

# %%
# # # json을 읽어보며 라벨을 어떻게 처리할 지 알아보자.
# import json
# with open('/content/drive/MyDrive/NIA 폐플라스틱 객체 검출 예측/Data/Train/annotation/PE/PE_074_10.json', 'r') as f:
#   json_data = json.loads(f.read())

# %%
# print(json_data)
